# %% [markdown]
# # Business Problem
# Name Matching
# Link the external data sources to ING's own basis administration.
#
# The task is to build a prototype model that matches any external data-source (S) to ING's ground-truth administration (G). The meatching should be based on name that appears in S only.
#
# The solution should provide a prediction for each entry in S whether:
# • It is in G à provide the id in G that this entry is matched to;
# • It is not in G à provide a -1 for these

# %% [markdown]
# ## Name Matching
# <img src="Images/name_matching.png">

# %% [markdown]
# ### Technical Approach
# Compute pairwise similarity score between names in the Ground Truth dataset and names in the external Train dataset and select one with the top similarity score ie. ~450k*~100k computations
# ### Implemented approach
# Compute similarity using sparse matrix multiplication/ dot product
# *	Slice the external source dataset into slices of 10,000 names each
# *	Pre-process the external source dataset and converts to tf-idf sparse matrix
# *	Compute dot product of test set tf-idf matrix with ground truth tf-idf matrix
# *	Select top one similarity result from the resulting matrix
# *	Save the final result as csv file

# %% [markdown]
# ### Descriptive Analysis

# %%
import pandas as pd
import numpy as np
import time
import warnings
warnings.filterwarnings('ignore')

# %%
groundTruth = pd.read_csv("Datasets/G.csv", sep='|')
print(list(groundTruth.columns.values))
print(groundTruth.head())
print(groundTruth.shape)
# Out:
# ['company_id', 'name']
#    company_id                        name
# 0      634022                  PRIMCOM SA
# 1      324497       The David Isaacs Fund
# 2      280848  Bramor Enterprises Limited
# 3      432662                NAVEXIM S.A.
# 4      524224              Magal Group SA
# (450256, 2)

# %%
companyCounts = groundTruth['company_id'].value_counts()
print(companyCounts.describe())
topCompanyCounts = companyCounts.nlargest(20)
# Out:
# count    450256.0
# mean          1.0
# std           0.0
# min           1.0
# 25%           1.0
# 50%           1.0
# 75%           1.0
# max           1.0
# Name: company_id, dtype: float64

# %%
sTrain = pd.read_csv("Datasets/STrain.csv", sep='|')
print(list(sTrain.columns.values))
print(sTrain.head())
print(sTrain.shape)
# Out:
# ['train_index', 'name', 'company_id']
#    train_index                                               name  company_id
# 0            0                        ATRION Immo bilien & Co. KG          -1
# 1            1                            MyTyme Inve stments Inc      356624
# 2            2                                     Financial USI.      510805
# 3            3  FlexShares Trust - FlexShares Morningstar Emer...      523467
# 4            4                                    Health Sinai SF      231108
# (100000, 3)

# %%
sTrainFilter = sTrain[(sTrain.company_id!=-1)]
print(sTrainFilter.shape)
matchingRecords = sTrainFilter.join(
    groundTruth.set_index("company_id"), on="company_id", lsuffix='_train', rsuffix='_GT')
# Out:
# (69652, 3)

# %% [markdown]
# ### Number of records in external train dataset matching with Ground Truth

# %%
print(matchingRecords.shape)
repeatedCounts = matchingRecords['company_id'].value_counts()
print(repeatedCounts.describe())
matchingRecords.head()
# Out:
# (69652, 4)
# count    64583.000000
# mean         1.078488
# std          0.283078
# min          1.000000
# 25%          1.000000
# 50%          1.000000
# 75%          1.000000
# max          4.000000
# Name: company_id, dtype: float64
#    train_index                                         name_train  company_id  \
# 1            1                            MyTyme Inve stments Inc      356624
# 2            2                                     Financial USI.      510805
# 3            3  FlexShares Trust - FlexShares Morningstar Emer...      523467
# 4            4                                    Health Sinai SF      231108
# 6            6                             LLC TEBS Fund II, ATAX      277891
#
#                                              name_GT
# 1                             MyTyme Investments Inc
# 2                        UBS Financial Services Inc.
# 3  FlexShares Trust - FlexShares Morningstar Emer...
# 4                     Sinai Health System Foundation
# 6                                  ATAX TEBS II, LLC

# %% [markdown]
# ### Text pre-processing

# %% [markdown]
# #### TF-IDF with N-grams

# %%
import re

def ngrams(string, n=3):
    string = re.sub(r'[,-./\']',r'', string)
    ngrams = zip(*[string[i:] for i in range(n)])
    return [''.join(ngram) for ngram in ngrams]

print('All 3-grams in "McDonalds":')
ngrams("McDonalds")
# Out:
# All 3-grams in "McDonalds":
# ['McD', 'cDo', 'Don', 'ona', 'nal', 'ald', 'lds']

# %%
# Can be parallelized
from sklearn.feature_extraction.text import TfidfVectorizer
company_names = groundTruth['name']
vectorizer = TfidfVectorizer(min_df=1, analyzer=ngrams)
ground_truth_matrix = vectorizer.fit_transform(company_names)

# %%
from scipy import sparse
sparse.save_npz("ground_truth.npz", ground_truth_matrix)

# %%
sTrainFil = sTrain[0:1000]
train_matrix = vectorizer.transform(sTrainFil['name'])
train_matrix
# Out:
# <1000x77626 sparse matrix of type '<class 'numpy.float64'>'
# 	with 21912 stored elements in Compressed Sparse Row format>

# %% [markdown]
# ### Compute Similarity using matrix multiplication/ dot product

# %%
# Below code calculates cosine similarities and return top results
# Implement LSA
def get_top_sim(sparse_row):
    nnz = sparse_row.getnnz()
    if nnz==0:
        return (0.0, None, -1)
    else:
        #arg_index = [np.argmax(sparse_row.data)]
        arg_index = np.argpartition(sparse_row.data, -1)[-1]
        match_id = sparse_row.indices[arg_index]
        result = (sparse_row.data[arg_index], groundTruth.loc[match_id]['name'], 
                     groundTruth.loc[match_id]['company_id'])
    return result
def cosine_similarities(trainMat, groundTruthMat):
    sim = trainMat.dot(groundTruthMat.T)
    #sim = trainMat*groundTruthMat.T.tocsc()
    return [get_top_sim(row) for row in sim]

# %%
def execute_matching(sTrainFil, match_df):
    test_matrix = vectorizer.transform(sTrainFil['name'])
    res = cosine_similarities(test_matrix, ground_truth_matrix)
    match_score, match_name , match_company_id = zip(*res)
    sTrainFil['match_company_id'] = np.array(match_company_id)
    sTrainFil['match_name'] = np.array(match_name)
    sTrainFil['match_score'] = np.array(match_score)
    match_df = match_df.append(sTrainFil)
    return match_df

# %% [markdown]
# ### Split external source train dataset into chunks for computation

# %%
def index_range(nrows, chunk_size):
    return range(1 * chunk_size, (nrows // chunk_size ) * chunk_size, chunk_size)

def split(dfm, chunk_size):
    indices = index_range(dfm.shape[0], chunk_size)
    return np.split(dfm, indices)

# %%
t1 = time.time()
slices = split(sTrain, 10000)
df_ = pd.DataFrame(columns=["train_index", "company_id", "name", "match_company_id", "match_name", "match_score"])
for sTrainFil in slices:
    df_ = execute_matching(sTrainFil, df_)
    print("Iteration completed")
t = time.time()-t1
print("Time for similarity computation:", t)
# Out:
# Time for similarity computation: 365.4136691093445

# %%
df_.head()
# Out:
#   company_id match_company_id  \
# 0         -1           250537
# 1     356624           356624
# 2     510805           152602
# 3     523467           523467
# 4     231108           231108
#
#                                           match_name  match_score  \
# 0                  ATRION Immobilien Verwaltung GmbH     0.498199
# 1                             MyTyme Investments Inc     0.901355
# 2                                  DS Financial, LLC     0.592322
# 3  FlexShares Trust - FlexShares Morningstar Emer...     0.962021
# 4                     Sinai Health System Foundation     0.541246
#
#                                                 name train_index
# 0                        ATRION Immo bilien & Co. KG           0
# 1                            MyTyme Inve stments Inc           1
# 2                                     Financial USI.           2
# 3  FlexShares Trust - FlexShares Morningstar Emer...           3
# 4                                    Health Sinai SF           4

# %%
df_.to_csv("result_train.csv", sep='|', header=True, index=False)

# %% [markdown]
# ### Data discrepancies

# %%
df_[(df_["match_company_id"] != df_["company_id"]) & (df_["match_score"] >=0.9)]
# Out:
#       company_id match_company_id  \
# 308       222824            26017
# 367           -1           454026
# 444           -1           633846
# 691       220892           417645
# 894       341955           528478
# 992           -1           629013
# 1112          -1           498563
# 1396      285406            36011
# 1470          -1           557136
# 1478          -1           617531
# 1658          -1           240187
# 1938          -1           521589
# 2697          -1           164443
# 2894      380886           460939
# 2920          -1           158693
# 2994          -1           188602
# 3111          -1           373856
# 3348       77595           618999
# 3424       36882           544775
# 3766          -1            26986
# 3792      613232           133175
# 3826      599440           479825
# 3869          -1           590220
# 3969          -1           240574
# 4055      504570            57476
# 4058          -1           502073
# 4275       76660           345064
# 4317          -1           495191
# 4463          -1           500415
# 4538          -1           122009
# ...          ...              ...
# 96413     436183           589944
# 96577         -1           130168
# 97077     362501           360050
# 97098     278957           390507
# 97235         -1           548808
# 97246     521885           209263
# 97280         -1           161430
# 97316     273411           464722
# 97361     537371           325375
# 97525         -1            64946
# 97582         -1           357635
# 97623         -1           587863
# 97924         -1           520757
# 97928     300719            58487
# 98010     220892           417645
# 98468         -1            72026
# 98515         -1           494122
# 98595     377900           242110
# 98655     574446           187685
# 98724         -1           391247
# 98802         -1           495278
# 98810     584041           213094
# 98954         -1           111364
# 98971     431571           161756
# 99062     577018            44094
# 99275      33538           639147
# 99497         -1           148006
# 99515     288515           177222
# 99575      40065           209163
# 99720     492754           438217
#
#                                               match_name  match_score  \
# 308                                             CARPINUS     1.000000
# 367                                  Cascade Corporation     1.000000
# 444                  Puerto Rico Fixed Income Fund, Inc.     0.914899
# 691                                            BS S.R.L.     1.000000
# 894                                          PEP II, LLC     1.000000
# 992                     LLOYDS UDT ASSET LEASING LIMITED     0.918610
# 1112              Raiffeisen-Pensionsfonds-Salzburg 2006     0.961262
# 1396                                        Siemens S.A.     1.000000
# 1470            Banque de Commerce et de Placements S.A.     0.969418
# 1478                                           A-TEX A/S     0.928437
# 1658                                             UL Inc.     1.000000
# 1938         Mandarine Funds - Mandarine Europe Microcap     0.940812
# 2697   Anlagestiftung Swiss Life - Obligationen Emerg...     0.905452
# 2894                     SL Beteiligungsgesellschaft mbH     0.920888
# 2920   Reliance Trust Institutional Retirement Trust ...     0.902651
# 2994                             FlexProtection Secure 2     0.917813
# 3111   GreenPoint Manufactured Housing Contract Trust...     0.904396
# 3348                                        DE-CA S.R.L.     1.000000
# 3424                        W Capital Partners III, L.P.     0.917222
# 3766                  Viaduct Invest FCP-SIF - Luxfund 4     0.946669
# 3792                                             ATP LLC     0.918864
# 3826          F.C. - SOCIETA' A RESPONSABILITA' LIMITATA     0.909095
# 3869                   Phoenician Resources Fund II, LLC     0.955153
# 3969                                         RES Limited     0.913265
# 4055                                                 GBS     1.000000
# 4058                                        PRIMA S.R.L.     0.905010
# 4275                  Private Placement Fund - Bonds USD     0.900137
# 4317             HLSS Servicer Advance Receivables Trust     0.976624
# 4463   JUSTICE SUPPORT SERVICES (NORFOLK AND SUFFOLK)...     0.903651
# 4538                                       GEMINI S.R.L.     1.000000
# ...                                                  ...          ...
# 96413                            Johnson & Johnson, Inc.     0.907476
# 96577  F&C LDI FUND - NOMINAL SWAP LDI SERIES 2 GBP 2...     0.926259
# 97077                                      A.T.I. S.R.L.     1.000000
# 97098                             Udlejer Rene Jørgensen     0.947011
# 97235                                   VGP CZ II., a.s.     1.000000
# 97246                                        ENCO S.R.L.     0.919712
# 97280                  General Reinsurance Australia Ltd     0.928294
# 97316                                             A.L.M.     1.000000
# 97361                BARCLAYS FUNDS - BARCLAYS BOND EURO     0.909326
# 97525        Lakefield UCITS-SICAV - Dynamic Global Core     0.932540
# 97582                JABCAP Global Balanced Fund Limited     0.905583
# 97623                                      FC Skyfall LP     0.954848
# 97924                       CHF - Holland Suites, L.L.C.     0.920860
# 97928                                                SRC     1.000000
# 98010                                          BS S.R.L.     1.000000
# 98468  CI Corporate Class Limited - International Equ...     0.928793
# 98515                                   NTS-Holding B.V.     0.955899
# 98595                                            HARMONY     0.922722
# 98655                                         Seitz GmbH     1.000000
# 98724                          Global Alpha Tilts Fund B     0.956178
# 98802                                    JUPITER-FONDS 1     0.909836
# 98810                               Fidelity Global Fund     1.000000
# 98954  iShares (DE) I Investmentaktiengesellschaft mi...     0.914661
# 98971  WisdomTree Issuer Public Limited Company - Wis...     0.905800
# 99062                                      MA.SI.NI. SRL     0.911276
# 99275                                                HPP     1.000000
# 99497  PIONEER STRUCTURED SOLUTION FUND - PIONEER UNI...     0.930003
# 99515                                     GIJV TX 5, LLC     1.000000
# 99575                                  Kebo Holding B.V.     1.000000
# 99720                               CornellCookson, Inc.     1.000000
#
#                                                     name train_index
# 308                                             CARPINUS         308
# 367                                  Cascade Corporation         367
# 444                Puerto Rico Fixed Income Fund VI, Inc         444
# 691                                            BS S.R.L.         691
# 894                                          PEP II, LLC         894
# 992                           LLOYDS UDT LEASING LIMITED         992
# 1112              Raiffeisen-Pensionsfonds-Salzburg 2004        1112
# 1396                                        Siemens S.A.        1396
# 1470              Commerce de Banque et de Placements SA        1470
# 1478                                           TeTEX A/S        1478
# 1658                                             UL Inc.        1658
# 1938                Mandarine Funds - Mandarine Microcap        1938
# 2697   Anlagestiftung Swiss Life - Obligationen Emerg...        2697
# 2894                        Beteiligungsgesellschaft mbH        2894
# 2920   Reliance Trust Institutional Retirement Trust ...        2920
# 2994                             FlexProtection Secure 4        2994
# 3111   GreenPointmanufactured Housing Contract Trust,...        3111
# 3348                                        AwDE.CA. SRL        3348
# 3424                             Capital Partners III LP        3424
# 3766                  Viaduct Invest FCP-SIF - Luxfund 3        3766
# 3792                                           CATP, LLC        3792
# 3826              FF - SOCIETA A RESPONSABILITA LIMITATA        3826
# 3869                    Phoenician Resources Fund I, LLC        3869
# 3969                                          ES Limited        3969
# 4055                                                 GBS        4055
# 4058                                        RI.MA S.R.L.        4058
# 4275          Private Limited Placement Fund - Bonds USD        4275
# 4317          HLSS Servicer Advance Receivables Trust II        4317
# 4463   JUSTICE SUPPORT SERVI CES (NORFOLK AND SUFFOLK...        4463
# 4538                                       GEMINI S.R.L.        4538
# ...                                                  ...         ...
# 96413                                       Johnson Inc.       96413
# 96577  F&C LDI FUND - NOMINAL SWAP LDI SERIES 2 GBP 2...       96577
# 97077                                      A.T.I. S.R.L.       97077
# 97098                        Udlejer Rene Jørgensen FUND       97098
# 97235                                   VGP CZ II., a.s.       97235
# 97246                                          RENCO SRL       97246
# 97280             General Reinsurance Life Australia Ltd       97280
# 97316                                               ALM.       97316
# 97361     BARCLAYS FUNDS - BARCLAYS BOND GmbH EURO CONV.       97361
# 97525        Lakefield UCITS-SICAV - Dynamic Global Bond       97525
# 97582         JABCAP Global Balanced Master Fund Limited       97582
# 97623                                     FC Skyfall Ltd       97623
# 97924                    CHF - Holland Suites II, L.L.C.       97924
# 97928                                                SRC       97928
# 98010                                          BS S.R.L.       98010
# 98468  CI Corporate Class Limited - US Equity Value C...       98468
# 98515                                    TS-Holding B.V.       98515
# 98595                                            cARMONY       98595
# 98655                                         Seitz GmbH       98655
# 98724                          Global Alpha Tilts Fund A       98724
# 98802                                    JUPITER-FONDS 2       98802
# 98810                               Fidelity Global Fund       98810
# 98954  iShares (DE) I Investmentaktiengesellschaft mi...       98954
# 98971  WisdomTree Issuer Public Limited Company - Wis...       98971
# 99062                                       ASINI S.R.L.       99062
# 99275                                                HPP       99275
# 99497  PIONEER STRUCTURED SOLUTION FUND - PIONEER UNI...       99497
# 99515                                     GIJV TX 5, LLC       99515
# 99575                                    Kebo Holding BV       99575
# 99720                               CornellCookson, Inc.       99720
#
# [627 rows x 6 columns]

# %%
groundTruth[(groundTruth["company_id"]==222824)]
# Out:
#         company_id      name
# 379074      222824  CARPINUS

# %%
result_fin = df_.copy()
result_fin['match_company_id'] = np.where(result_fin['match_score']<0.60, -1, result_fin['match_company_id'])
result_fin['match_name'] = np.where(result_fin['match_score']<0.60, "NaN",result_fin['match_name'])

# %%
print("matched incorrect as ‘not G’, cost=1: ")
print(len(result_fin[(result_fin['company_id']!=-1) & (result_fin['match_company_id']==-1)]))
print("matched incorrect to G, cost=5: ")
print(len(result_fin[(result_fin['company_id']==-1) & (result_fin['match_company_id']!=-1)]))
print("matched correct, cost=0: ")
print(len(result_fin[(result_fin['company_id']==result_fin['match_company_id']) & (result_fin['company_id']!=-1)]))
print("no match present: ")
print(len(sTrainFil[(sTrainFil['company_id']==-1)]))
# Out:
# matched incorrect as ‘not G’, cost=1:
# 17559
# matched incorrect to G, cost=5:
# 9248
# matched correct, cost=0:
# 47488
# no match present:
# 311

# %%
import pickle
pickle.dump(vectorizer, open("vectorizer.pickle", "wb"))
#vectorizer = pickle.load(open("vectorizer.pickle"), "rb")
