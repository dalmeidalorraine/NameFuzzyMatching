# %% [markdown]
# All data is provided as plain text column separated files:
# * Column separated by ‘|’ (bar), one line per entry;
# * the test set will have the same size as STrain provided to you now (hence, no memory issues during test).
# We provide you up-front with three datasets: G, STrain and sample_submission
# * G has as columns:
#     * company_id: the id of the company in our ground-truth administration
#     * name: the name of the company in our ground-truth administration
# * STrain has as columns:
#     * train_index: an index of the company in the external source dataset;
#     * name: the name of the company as represented in the external source dataset;
#     * company_id: the correct match of this entry to G. Is -1 if correct label is ‘not in G’, otherwise corresponds to G_id
# * sample_submission has as columns:
#     * test_index: index of the company in an external source dataset (note: different index from STrain, full STest will only be provided during the interview);
#     * company_id: the predicted match of this entry to G. Note that in this file, these are randomly generated predictions.
#
# You need to design, code and train a model that predicts company_id, minimizing the cost function as specified on the previous page
# Please make sure that your trained model:
#
# * accepts as input a plain text file of the format STest, containing two columns test_index and name;
# * runs from the command line, using as input the path to the file STest;
# * prediction time should be ‘near real time’, i.e. about 1 minute for 10,000 entries (on a regular laptop);
# * It should return a file with the above plain text format, including the columns test_index and company_id (an example submission is provided).

# %%
import pandas as pd
import numpy as np
import time
import warnings
warnings.filterwarnings('ignore')

# %%
groundTruth = pd.read_csv("Datasets/G.csv", sep='|')
print(list(groundTruth.columns.values))
print(groundTruth.head())
print(groundTruth.shape)
# Out:
# ['company_id', 'name']
#    company_id                        name
# 0      634022                  PRIMCOM SA
# 1      324497       The David Isaacs Fund
# 2      280848  Bramor Enterprises Limited
# 3      432662                NAVEXIM S.A.
# 4      524224              Magal Group SA
# (450256, 2)

# %%
companyCounts = groundTruth['company_id'].value_counts()
print(companyCounts.describe())
topCompanyCounts = companyCounts.nlargest(20)
# Out:
# count    450256.0
# mean          1.0
# std           0.0
# min           1.0
# 25%           1.0
# 50%           1.0
# 75%           1.0
# max           1.0
# Name: company_id, dtype: float64

# %%
sTrain = pd.read_csv("Datasets/STrain.csv", sep='|')
print(list(sTrain.columns.values))
print(sTrain.head())
print(sTrain.shape)
# Out:
# ['train_index', 'name', 'company_id']
#    train_index                                               name  company_id
# 0            0                        ATRION Immo bilien & Co. KG          -1
# 1            1                            MyTyme Inve stments Inc      356624
# 2            2                                     Financial USI.      510805
# 3            3  FlexShares Trust - FlexShares Morningstar Emer...      523467
# 4            4                                    Health Sinai SF      231108
# (100000, 3)

# %%
sTrainFilter = sTrain[(sTrain.company_id!=-1)]
print(sTrainFilter.shape)
matchingRecords = sTrainFilter.join(
    groundTruth.set_index("company_id"), on="company_id", lsuffix='_train', rsuffix='_GT')
# Out:
# (69652, 3)

# %%
print(matchingRecords.shape)
repeatedCounts = matchingRecords['company_id'].value_counts()
#print(repeatedCounts.describe())
matchingRecords.head()
# Out:
# (69652, 4)
#    train_index                                         name_train  company_id  \
# 1            1                            MyTyme Inve stments Inc      356624
# 2            2                                     Financial USI.      510805
# 3            3  FlexShares Trust - FlexShares Morningstar Emer...      523467
# 4            4                                    Health Sinai SF      231108
# 6            6                             LLC TEBS Fund II, ATAX      277891
#
#                                              name_GT
# 1                             MyTyme Investments Inc
# 2                        UBS Financial Services Inc.
# 3  FlexShares Trust - FlexShares Morningstar Emer...
# 4                     Sinai Health System Foundation
# 6                                  ATAX TEBS II, LLC

# %%
import numpy as np
test = [x for x in np.array(sTrainFilter['company_id']) if x in groundTruth['company_id']]
len(test)
# Out:
# 48764

# %% [markdown]
# #### TF-IDF with N-grams

# %%
import re

def ngrams(string, n=3):
    string = re.sub(r'[,-./]|\sBD',r'', string)
    ngrams = zip(*[string[i:] for i in range(n)])
    return [''.join(ngram) for ngram in ngrams]

print('All 3-grams in "McDonalds":')
ngrams('McDonalds')
# Out:
# All 3-grams in "McDonalds":
# ['McD', 'cDo', 'Don', 'ona', 'nal', 'ald', 'lds']

# %%
# Can be parallelized
from sklearn.feature_extraction.text import TfidfVectorizer
company_names = groundTruth['name']
vectorizer = TfidfVectorizer(min_df=1, analyzer=ngrams)
ground_truth_matrix = vectorizer.fit_transform(company_names)

# %%
sTrainFil = sTrain[0:10000]
train_matrix = vectorizer.transform(sTrainFil['name'])
train_matrix
# Out:
# <10000x78817 sparse matrix of type '<class 'numpy.float64'>'
# 	with 223152 stored elements in Compressed Sparse Row format>

# %%
# Below code calculates cosine similarities and return top results
# Implement LSA
def get_top_sim(sparse_row):
    nnz = sparse_row.getnnz()
    if nnz==0:
        return (0.0, None, -1)
    else:
        #arg_index = [np.argmax(sparse_row.data)]
        arg_index = np.argpartition(sparse_row.data, -1)[-1]
        match_id = sparse_row.indices[arg_index]
        result = (sparse_row.data[arg_index], groundTruth.loc[match_id]['name'], 
                     groundTruth.loc[match_id]['company_id'])
    return result
def cosine_similarities(trainMat, groundTruthMat):
    sim = trainMat.dot(groundTruthMat.T)
    #sim = trainMat*groundTruthMat.T.tocsc()
    return [get_top_sim(row) for row in sim]

# %%
import time
t1 = time.time()
res = cosine_similarities(train_matrix, ground_truth_matrix)
t = time.time()-t1
print("Time taken for computing similarities:", t)
# Out:
# Time taken for computing similarities: 36.37892985343933

# %%
match_score, match_name , match_company_id = zip(*res)
sTrainFil['match_name'] = np.array(match_name)
sTrainFil['match_company_id'] = np.array(match_company_id)
sTrainFil['match_score'] = np.array(match_score)

# %%
sTrainFil
# Out:
#       train_index                                               name  \
# 0               0                        ATRION Immo bilien & Co. KG
# 1               1                            MyTyme Inve stments Inc
# 2               2                                     Financial USI.
# 3               3  FlexShares Trust - FlexShares Morningstar Emer...
# 4               4                                    Health Sinai SF
# 5               5                            Auto markt Dinser sGmbH
# 6               6                             LLC TEBS Fund II, ATAX
# 7               7                   Windermere reds Acquisitions LLC
# 8               8                     Les Eoliennes de Saint Fraigne
# 9               9  Tatra Asset Management, spárv. spol., a.s., de...
# 10             10                                    J. H. Born GmbH
# 11             11                                           Enfo Oyj
# 12             12                                     Inteventor ApS
# 13             13                                    betaPharm, Inc.
# 14             14                                               WL1M
# 15             15                                     RA iWeibull AB
# 16             16            Yuanta SICAV Asset Mana. (H.K.) Limited
# 17             17                Health Aurora Careinc. Master Trust
# 18             18                              CH SH RAC Ltd, L.L.C.
# 19             19                                                CAC
# 20             20                                               EAIL
# 21             21                                        NEU PROCESS
# 22             22  Funds Global Vang. Public Limited Company - Fu...
# 23             23                                            TINIESA
# 24             24                              BW HoldCo LLC LIMITED
# 25             25                                   Services Comitno
# 26             26                                IMMO. SILVIA S.R.L.
# 27             27                           REPULIC ASSET MANAGEMENT
# 28             28                       JR  Normand Inve stment Inc.
# 29             29                         HSBC SPEcCIAL EUROPE SITU.
# ...           ...                                                ...
# 9970         9970                                LOS VZAQUEZ DE S.L.
# 9971         9971                                      Clariet, Inc.
# 9972         9972                                    Funds. Seies II
# 9973         9973                   "Ayrc- Interiors" sp.z oo  sp.k.
# 9974         9974  SEF SICAV Part II - Capital Strategy Preservat...
# 9975         9975                      MC Real Property Holdings LLC
# 9976         9976    pelaware Investments Divi dend and Inc Company.
# 9977         9977  Galaxy FP uund - Green. FP Master uund uund (5...
# 9978         9978                                     MRS FUND S WDS
# 9979         9979                            MS "GmbH Stra. & Co. KG
# 9980         9980                           BORAUinversions SICAV SA
# 9981         9981                  Benson Windfarmholdings 1, L.L.C.
# 9982         9982                           Ed. rPoj TRUST. Omega NV
# 9983         9983                               FORM Fund-PLAST S.A.
# 9984         9984                                    Investemnt Fund
# 9985         9985                                     LETHOME S.R.L.
# 9986         9986  MINERVO CONTROLtehnično vodenje, svet ovanje, ...
# 9987         9987                                     Crossroads, LP
# 9988         9988              Lire Emblem Aggr essive Growth Portf.
# 9989         9989                                         Grund. Lne
# 9990         9990                                           BCGG Inc
# 9991         9991                     Canusa Hershman Recycling, LLC
# 9992         9992                                 mSuld. Beheer B.V.
# 9993         9993                            QQM EQUTIY HEDGE Equity
# 9994         9994  Series Investment Trust - Gratry Inter nationa...
# 9995         9995  STE CONFRATERNELLE D'EXPLOITATION DE REPARTITI...
# 9996         9996                  CREDIT IMMOBILIER DE FRANCE OUEST
# 9997         9997                              Central Park Prop. LP
# 9998         9998                            Energy Renew. EDF, Inc.
# 9999         9999                                        CI AT Funnd
#
#       company_id                                         match_name  \
# 0             -1                  ATRION Immobilien Verwaltung GmbH
# 1         356624                             MyTyme Investments Inc
# 2         510805                                  DS Financial, LLC
# 3         523467  FlexShares Trust - FlexShares Morningstar Emer...
# 4         231108                     Sinai Health System Foundation
# 5             -1                               Baumarkt Bender GmbH
# 6         277891                                  ATAX TEBS II, LLC
# 7         205639               Breds Windermere Acquisitions L.L.C.
# 8             -1                           Eoliennes de Lorraine SA
# 9         589052  Tatra Asset Management, správ. spol., a.s., de...
# 10            -1                                    Just Born, Inc.
# 11          9529                                           Enfo Oyj
# 12            -1                                          Ventor AS
# 13            -1                                   ViaPharma s.r.o.
# 14            -1                                             TKWL-1
# 15        253824                                      RA Weibull AB
# 16            -1                   AP Asset Management (HK) Limited
# 17        524676               Aurora Health Care Inc. Master Trust
# 18        250654                                          HRAC, LLC
# 19        214855                                       CACCO S.R.L.
# 20        543095                                CEAI-Stratford, LLC
# 21        151846                                        NEU PROCESS
# 22        417542  Vanguard Funds Public Limited Company - Vangua...
# 23        293343                                            TINIESA
# 24         72571                                      BW HoldCo LLC
# 25            -1                            Bitnet Services Limited
# 26        524188                          IMMOBILIARE SILVIA S.R.L.
# 27            -1                            CM CIC ASSET MANAGEMENT
# 28        340707                                  J.R. Normand Inc.
# 29            -1                                   HSBC EUROPE B.V.
# ...          ...                                                ...
# 9970      237475                       LOS VAZQUEZ DE ARACENA, S.L.
# 9971        4698                                     Clarient, Inc.
# 9972      586789                                Fund of Funds II LP
# 9973      237060                   "Arc- Interiors" sp.z o.o. sp.k.
# 9974      192978  SEF SICAV Part II - Capital Preservation Strategy
# 9975      412394                     MBC Real Property Holdings LLC
# 9976      306678  Delaware Investments Dividend and Income Fund,...
# 9977          -1     Galaxy Plus Fund - Quest Master Fund (517) LLC
# 9978      389059                            THE EM-ES FUND SPC LTD.
# 9979      286024                           MS "Glory" GmbH & Co. KG
# 9980      355737                           Plusinversion, SICAV, SA
# 9981      638624           Benson Creek Windfarm Holdings 1, L.L.C.
# 9982      430514                                 Ed. Proj. Omega NV
# 9983       60123                                     SoundPLAN GmbH
# 9984          -1    AIM Investment Funds (Invesco Investment Funds)
# 9985          -1                                        DOME S.R.L.
# 9986          -1                            SAROS svetovanje d.o.o.
# 9987          -1                                    Crossroads Bank
# 9988      340284     Empire Life Emblem Aggressive Growth Portfolio
# 9989          -1                                       I Grund B.V.
# 9990      196617                                                CGG
# 9991      165024                     Canusa Hershman Recycling, LLC
# 9992      335782                              H. Mulder Beheer B.V.
# 9993       77064                               QQM EQUITY HEDGE EUR
# 9994      435358  Investment Managers Series Trust - Gratry Inte...
# 9995       73218  STE CONFRATERNELLE D'EXPLOITATION DE REPARTITI...
# 9996          -1           CREDIT IMMOBILIER DE FRANCE-CENTRE OUEST
# 9997      601124                                   Central Park LLC
# 9998          -1                                         Renew, LLC
# 9999      214109                                  Sunndal Energi KF
#
#       match_company_id  match_score
# 0               250537     0.498201
# 1               356624     0.901331
# 2               152602     0.592161
# 3               523467     0.962004
# 4               231108     0.541243
# 5               259391     0.287415
# 6               277891     0.634353
# 7               205639     0.822906
# 8               371703     0.542665
# 9               589052     0.671565
# 10              359697     0.411228
# 11                9529     1.000000
# 12              632219     0.498541
# 13              389236     0.450751
# 14               86858     0.597900
# 15              253824     0.716604
# 16              413043     0.597468
# 17              524676     0.791164
# 18              576551     0.408712
# 19              568808     0.525874
# 20              481539     0.365712
# 21              151846     1.000000
# 22              417542     0.636138
# 23              293343     1.000000
# 24               72571     0.845723
# 25              607912     0.512491
# 26              168375     0.707148
# 27              422426     0.673857
# 28              340707     0.611260
# 29              622198     0.592106
# ...                ...          ...
# 9970            237475     0.489832
# 9971              4698     0.751045
# 9972             88208     0.333491
# 9973            237060     0.773974
# 9974            192978     0.908316
# 9975            412394     0.864452
# 9976            306678     0.704880
# 9977            310973     0.410124
# 9978             89969     0.275182
# 9979            389906     0.448067
# 9980            310198     0.551339
# 9981            638624     0.694159
# 9982            430514     0.602592
# 9983            610847     0.529779
# 9984            462050     0.464420
# 9985            275332     0.518556
# 9986            554211     0.358860
# 9987            269092     0.860509
# 9988            340284     0.719483
# 9989            297344     0.417138
# 9990            541096     0.588088
# 9991            165024     1.000000
# 9992            610804     0.530970
# 9993            399915     0.659871
# 9994            435358     0.675242
# 9995             73218     0.941747
# 9996            538602     0.878885
# 9997            300535     0.669549
# 9998            520415     0.404834
# 9999            556303     0.358541
#
# [10000 rows x 6 columns]
